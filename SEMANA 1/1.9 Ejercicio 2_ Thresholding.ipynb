# %%
import numpy as np # n-dim
import skimage #scikit-image
import matplotlib.pyplot as plt # mostrar imágenes

# %%
im = skimage.data.coins()

# %%
im
# Out:
# array([[ 47, 123, 133, ...,  14,   3,  12],
#        [ 93, 144, 145, ...,  12,   7,   7],
#        [126, 147, 143, ...,   2,  13,   3],
#        ...,
#        [ 81,  79,  74, ...,   6,   4,   7],
#        [ 88,  82,  74, ...,   5,   7,   8],
#        [ 91,  79,  68, ...,   4,  10,   7]], shape=(303, 384), dtype=uint8)

# %%
plt.imshow(im, cmap='gray')

# %%
im.shape # escala de grises
# Out:
# (303, 384)

# %%
303*384 # número de píxeles
# Out:
# 116352

# %%
im = skimage.data.coins()
plt.imshow(im, cmap='gray')

# %%
#@title Cambiar valor de t { run: "auto" }
t = 155 #@param {type:"slider", min:0, max:255, step:1}
im_th = im.copy()
im_th[im_th<t] = 0
im_th[im_th>=t] = 255
# binarizar la imagen (2 valores)
plt.figure()
plt.imshow(im_th, cmap='gray')

# %%
im.ravel()
# contabilizar los px para cada nivel de intensidad
# nivel 0 -> 47 px
# nivel 1 -> 123 px
# ...
# nivel 255 -> 7 px

# %%
r = im.ravel()

# %%
r

# %%
r.shape

# %%
plt.hist(r, bins=255);
