# %%
pip install scikit-image
# Out:
# Requirement already satisfied: scikit-image in c:\users\usuario\appdata\local\programs\python\python313\lib\site-packages (0.26.0)
# Requirement already satisfied: numpy>=1.24 in c:\users\usuario\appdata\local\programs\python\python313\lib\site-packages (from scikit-image) (2.2.6)
# Requirement already satisfied: scipy>=1.11.4 in c:\users\usuario\appdata\local\programs\python\python313\lib\site-packages (from scikit-image) (1.15.3)
# Requirement already satisfied: networkx>=3.0 in c:\users\usuario\appdata\local\programs\python\python313\lib\site-packages (from scikit-image) (3.5)
# Requirement already satisfied: pillow>=10.1 in c:\users\usuario\appdata\local\programs\python\python313\lib\site-packages (from scikit-image) (11.2.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\users\usuario\appdata\local\programs\python\python313\lib\site-packages (from scikit-image) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\usuario\appdata\local\programs\python\python313\lib\site-packages (from scikit-image) (2026.3.3)
# Requirement already satisfied: packaging>=21 in c:\users\usuario\appdata\roaming\python\python313\site-packages (from scikit-image) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\usuario\appdata\local\programs\python\python313\lib\site-packages (from scikit-image) (0.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
from skimage.io import imread, imsave
import matplotlib.pyplot as plt

# %%
im = imread('logo-uni.jpeg', as_gray=True)
# Out:
# c:\Users\Usuario\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio\plugins\spe.py:506: UserWarning: The file header of d:\Programacion_Grafica\SEMANA 1\logo-uni.jpeg claims there are 1534040150 frames, but there are actually 67 frames.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 im = imread('logo-uni.jpeg', as_gray=True)
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python313\Lib\site-packages\skimage\_shared\utils.py:386, in deprecate_parameter.__call__.<locals>.fixed_func(*args, **kwargs)
#     382     elif self.new_name is not None:
#     383         # Assign old value to new one
#     384         kwargs[self.new_name] = deprecated_value
# --> 386 return func(*args, **kwargs)
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python313\Lib\site-packages\skimage\io\_io.py:95, in imread(fname, as_gray, plugin, **plugin_args)
#      93         if img.shape[2] == 4:
#      94             img = rgba2rgb(img)
# ---> 95         img = rgb2gray(img)
#      97 return img
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python313\Lib\site-packages\skimage\_shared\utils.py:587, in channel_as_last_axis.__call__.<locals>.fixed_func(*args, **kwargs)
#     584 channel_axis = kwargs.get('channel_axis', None)
#     586 if channel_axis is None:
# --> 587     return func(*args, **kwargs)
#     589 # TODO: convert scalars to a tuple in anticipation of eventually
#     590 #       supporting a tuple of channel axes. Right now, only an
#     591 #       integer or a single-element tuple is supported, though.
#     592 if np.isscalar(channel_axis):
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python313\Lib\site-packages\skimage\color\colorconv.py:982, in rgb2gray(rgb, channel_axis)
#     941 @channel_as_last_axis(multichannel_output=False)
#     942 def rgb2gray(rgb, *, channel_axis=-1):
#     943     """Compute luminance of an RGB image.
#     944
#     945     Parameters
#    (...)    980     >>> img_gray = rgb2gray(img)
#     981     """
# --> 982     rgb = _prepare_colorarray(rgb)
#     983     coeffs = np.array([0.2125, 0.7154, 0.0721], dtype=rgb.dtype)
#     984     return rgb @ coeffs
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python313\Lib\site-packages\skimage\color\colorconv.py:170, in _prepare_colorarray(arr, force_copy, channel_axis)
#     165 if arr.shape[channel_axis] != 3:
#     166     msg = (
#     167         f'the input array must have size 3 along `channel_axis`, '
#     168         f'got {arr.shape}'
#     169     )
# --> 170     raise ValueError(msg)
#     172 float_dtype = _supported_float_type(arr.dtype)
#     173 if float_dtype == np.float32:
#
# ValueError: the input array must have size 3 along `channel_axis`, got (67, 37191, 9)

# %%
plt.imshow(im, cmap='gray')

# %%
sd = 1.2
image_stack = []
stack_size = 1000
for i in range(stack_size):
  im_noise = im + np.random.normal(0, sd, im.shape)
  # Escalar y convertir a uint8 para guardarlo como PNG
  im_noise = np.clip(im_noise, 0, 1)  # normalizar en rango de 0 a 1
  im_noise = (im_noise * 255).astype(np.uint8) # Escalar de nuevo a uint8

  # imsave('im_{}.png'.format(i), im_noise )
  image_stack.append(im_noise)

# %%
image_stack = np.array(image_stack)
image_stack.shape
img = image_stack.mean(axis = 0)
plt.imshow(img, cmap = 'gray')

# %%
# !zip -R reto.zip '*.png'

# %%
image_stack = np.array(image_stack)
image_stack.shape

# %%
plt.figure(figsize = (15,10))
ncols = 5
nrows = 5
for i in range(ncols*nrows):
  plt.subplot(nrows,ncols, i+1)
  plt.axis('off')
  plt.imshow(image_stack[i], cmap='gray')
