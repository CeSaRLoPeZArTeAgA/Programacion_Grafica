# %%
# !gdown --id 1-GfyMBGbet_xVwzwHSkjNcta5skCmE0X
# Out:
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:139: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1-GfyMBGbet_xVwzwHSkjNcta5skCmE0X
# From (redirected): https://drive.google.com/uc?id=1-GfyMBGbet_xVwzwHSkjNcta5skCmE0X&confirm=t&uuid=3ddf10e1-90f1-42a4-920e-51afb29e90ac
# To: /content/reto.zip
# 100% 89.9M/89.9M [00:01<00:00, 46.6MB/s]

# %%
# !unzip reto.zip
# Out:
# Archive:  reto.zip
#   inflating: im_866.png
#   inflating: im_258.png
#   inflating: im_206.png
#   inflating: im_577.png
#   inflating: im_521.png
#   inflating: im_44.png
#   inflating: im_945.png
#   inflating: im_591.png
#   inflating: im_380.png
#   inflating: im_185.png
#   inflating: im_407.png
#   inflating: im_28.png
#   inflating: im_640.png
#   inflating: im_17.png
#   inflating: im_856.png
#   inflating: im_452.png
#   inflating: im_371.png
#   inflating: im_395.png
#   inflating: im_776.png
#   inflating: im_168.png
#   inflating: im_852.png
#   inflating: im_283.png
#   inflating: im_717.png
#   inflating: im_843.png
#   inflating: im_154.png
#   inflating: im_140.png
#   inflating: im_402.png
#   inflating: im_831.png
#   inflating: im_292.png
#   inflating: im_54.png
#   inflating: im_581.png
#   inflating: im_191.png
#   inflating: im_4.png
#   inflating: im_897.png
#   inflating: im_71.png
#   inflating: im_461.png
#   inflating: im_280.png
# ...

# %%
import numpy as np
from skimage.io import imread, imsave
import matplotlib.pyplot as plt

image_stack = []
stack_size = 1000
for i in range(stack_size):
  im = imread('im_{}.png'.format(i), as_gray = True)
  image_stack.append(im)

# %%
image_stack[0]
# Out:
# array([[ 89,   0,   0, ..., 152, 130, 171],
#        [ 82,   0, 228, ...,   0,   0, 255],
#        [  0, 255, 255, ...,  63,   0,   0],
#        ...,
#        [  0,   0, 117, ...,   0,   0, 255],
#        [216,   0,   0, ..., 244, 140,  38],
#        [165, 147,   0, ..., 255,   0,   0]], dtype=uint8)

# %%
# 1. image_stack a np.array
image_stack = np.array(image_stack)
image_stack.shape
# 2. media de la imagen -> se acerquen a 0
image = image_stack.mean(axis = 0)
# 3. mostrar la imagen
plt.imshow(image, cmap = 'gray')

# %%
im_demo = imread('im_2.png')
plt.imshow(im_demo, cmap = 'gray')

# %%
# Revelar la imagen!!
