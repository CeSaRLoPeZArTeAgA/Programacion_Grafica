# %%
import numpy as np
import skimage #scikit-image
from skimage.io import imread
import matplotlib.pyplot as plt

# %% [markdown]
# ### Lectura de la imagen

# %%
# !gdown 19e9LL_xl63yPOYD_53Ev3vOd1N3viKeT

# %%
url = 'negative_image.jpg'
im = imread(url)
im = im[:,:,0] # <--- color Red (Rojo)
# ::-1 -> invertir
# :250 -> tomar los primeros 250 px
# 250: -> tomar los últimos 250 px
plt.imshow(im, cmap='gray')

# %% [markdown]
# ### Revelar la imagen

# %%
im

# %%
im.shape

# %%
#modificar
im_revelada1 = 255. - im
# intento con -im

# %%
im_revelada2 = - im

# %%
plt.imshow(im_revelada1, cmap='gray')

# %%
im

# %%
im_revelada1 # 255. - im

# %%
im_revelada2 # -im

# %%
plt.imshow(im_revelada2, cmap='gray')

# %% [markdown]
# ### Mostrar imagen revelada

# %%
plt.imshow(im_revelada1, cmap='gray')

# %%
#modificar
imagen_negativo = 255. - im_revelada1

# %%
plt.imshow(imagen_negativo, cmap='gray')

# %%
im_revelado.shape

# %%
plt.imshow(im_revelado, cmap='gray')
