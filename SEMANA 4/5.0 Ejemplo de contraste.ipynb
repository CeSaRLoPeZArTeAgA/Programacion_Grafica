# %%
# !wget https://pythonexamples.org/wp-content/uploads/2019/03/original-image-1.png -O sample-image.png

# %%
from PIL import Image, ImageEnhance

#read the image
im = Image.open("sample-image.png")

# %%
im

# %%
im.convert('L')

# %%
#image brightness enhancer
enhancer = ImageEnhance.Contrast(im)

factor = 1 #gives original image
im_output = enhancer.enhance(factor)
im_output.save('original-image.png')
im_output

# %%
im_output.convert('L')

# %%
factor = 0.5 #decrease constrast
im_output = enhancer.enhance(factor)
im_output.save('less-contrast-image.png')
im_output

# %%
im_output.convert('L')

# %%
factor = 0.1 #decrease constrast
im_output = enhancer.enhance(factor)
im_output.save('less-contrast-image.png')
im_output

# %%
im_output.convert('L')

# %%
factor = 1.5 #increase contrast
im_output = enhancer.enhance(factor)
im_output.save('more-contrast-image.png')
im_output

# %%
im_output.convert('L')
